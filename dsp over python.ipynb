# %%
### Python via Jupyter

# %%
import numpy as np

# %% [markdown]
# ### Import only display() from IPython module

# %%
from IPython.display import display

# %%
# %%timeit
python_list_1 = list(range(5000000))
python_list_2 = list(range(5000000))
# Out:
# 1 loop, best of 3: 234 ms per loop

# %%
# %%timeit
np_array_1 = np.arange(5000000)
np_array_2 = np.arange(5000000)
# Out:
# 100 loops, best of 3: 18.6 ms per loop

# %% [markdown]
# ## Signal Processing using Python

# %% [markdown]
# Notes:
# * You can use matplotlib inside your IPython Notebook by calling *%matplotlib inline*, which has the advantage of keeping your plots in one place
# * With *%matplotlib inline*, the output of plotting commands is displayed inline within the notebook, directly below the code cell that produced it. The resulting plots will then also be stored in the notebook document.

# %%
# for plotting with matplotlib
# %matplotlib inline
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp');

# %%
freq = 50 #F
period = 1/freq # T=1/F
twoperiod = period * 2
amplitude=2

# %%
t = np.linspace(0,time,500,endpoint=True)
x=2*3.14*freq*t
